# %% [markdown]
# # Assignment 1

# %% [markdown]
# ## Basic setup

# %%
# %matplotlib inline

# %% [markdown]
# Define path to data: (It's a good idea to put it in a subdirectory of your notebooks folder, and then exclude that directory from git control by adding it to .gitignore.)

# %%
path = "data/dogscatsredux"
#path = "data/dogscats/sample"

# %% [markdown]
# A few basic libraries that we'll need for the initial exercises:

# %%
from __future__ import division,print_function

import os, json
from glob import glob
import numpy as np
np.set_printoptions(precision=4, linewidth=100)
from matplotlib import pyplot as plt

# %% [markdown]
# We have created a file most imaginatively called 'utils.py' to store any little convenience functions we'll want to use. We will discuss these as we use them.

# %%
import utils; reload(utils)
from utils import plots
# Out:
# Using Theano backend.
# Using gpu device 0: Tesla K80 (CNMeM is disabled, cuDNN 5103)
# /home/ubuntu/anaconda2/lib/python2.7/site-packages/theano/sandbox/cuda/__init__.py:600: UserWarning: Your cuDNN version is more recent than the one Theano officially supports. If you see any problems, try updating Theano or downgrading cuDNN to version 5.
#   warnings.warn(warn)

# %% [markdown]
# # Download data set from Kaggle

# %%
# !pip install kaggle-cli
#!kg config -g -u username -p password -c dogs-vs-cats-redux-kernels-edition
# !kg download
# Out:
# Starting new HTTPS connection (1): www.kaggle.com
# downloading https://www.kaggle.com/c/dogs-vs-cats-redux-kernels-edition/download/test.zip
# Starting new HTTPS connection (1): kaggle2.blob.core.windows.net
# downloading https://www.kaggle.com/c/dogs-vs-cats-redux-kernels-edition/download/train.zip
# downloading https://www.kaggle.com/c/dogs-vs-cats-redux-kernels-edition/download/sample_submission.csv
# Resetting dropped connection: www.kaggle.com

# %% [markdown]
# # Move and extract zip files

# %%
# !mv train.zip {path}
# !mv test.zip {path}

# %%
# !unzip {path}/train.zip -d {path}
# !unzip {path}/test.zip -d {path}
# Out:
# Archive:  data/dogscatsredux/train.zip
#    creating: data/dogscatsredux/train/
#   inflating: data/dogscatsredux/train/cat.0.jpg
#   inflating: data/dogscatsredux/train/cat.1.jpg
#   inflating: data/dogscatsredux/train/cat.10.jpg
#   inflating: data/dogscatsredux/train/cat.100.jpg
#   inflating: data/dogscatsredux/train/cat.1000.jpg
#   inflating: data/dogscatsredux/train/cat.10000.jpg
#   inflating: data/dogscatsredux/train/cat.10001.jpg
#   inflating: data/dogscatsredux/train/cat.10002.jpg
#   inflating: data/dogscatsredux/train/cat.10003.jpg
#   inflating: data/dogscatsredux/train/cat.10004.jpg
#   inflating: data/dogscatsredux/train/cat.10005.jpg
#   inflating: data/dogscatsredux/train/cat.10006.jpg
#   inflating: data/dogscatsredux/train/cat.10007.jpg
#   inflating: data/dogscatsredux/train/cat.10008.jpg
#   inflating: data/dogscatsredux/train/cat.10009.jpg
#   inflating: data/dogscatsredux/train/cat.1001.jpg
#   inflating: data/dogscatsredux/train/cat.10010.jpg
#   inflating: data/dogscatsredux/train/cat.10011.jpg
#   inflating: data/dogscatsredux/train/cat.10012.jpg
#   inflating: data/dogscatsredux/train/cat.10013.jpg
#   inflating: data/dogscatsredux/train/cat.10014.jpg
#   inflating: data/dogscatsredux/train/cat.10015.jpg
#   inflating: data/dogscatsredux/train/cat.10016.jpg
#   inflating: data/dogscatsredux/train/cat.10017.jpg
#   inflating: data/dogscatsredux/train/cat.10018.jpg
#   inflating: data/dogscatsredux/train/cat.10019.jpg
#   inflating: data/dogscatsredux/train/cat.1002.jpg
#   inflating: data/dogscatsredux/train/cat.10020.jpg
#   inflating: data/dogscatsredux/train/cat.10021.jpg
#   inflating: data/dogscatsredux/train/cat.10022.jpg
#   inflating: data/dogscatsredux/train/cat.10023.jpg
#   inflating: data/dogscatsredux/train/cat.10024.jpg
#   inflating: data/dogscatsredux/train/cat.10025.jpg
#   inflating: data/dogscatsredux/train/cat.10026.jpg
#   inflating: data/dogscatsredux/train/cat.10027.jpg
#   inflating: data/dogscatsredux/train/cat.10028.jpg
#   inflating: data/dogscatsredux/train/cat.10029.jpg
#   inflating: data/dogscatsredux/train/cat.1003.jpg
#   inflating: data/dogscatsredux/train/cat.10030.jpg
#   inflating: data/dogscatsredux/train/cat.10031.jpg
#   inflating: data/dogscatsredux/train/cat.10032.jpg
#   inflating: data/dogscatsredux/train/cat.10033.jpg
#   inflating: data/dogscatsredux/train/cat.10034.jpg
#   inflating: data/dogscatsredux/train/cat.10035.jpg
#   inflating: data/dogscatsredux/train/cat.10036.jpg
#   inflating: data/dogscatsredux/train/cat.10037.jpg
#   inflating: data/dogscatsredux/train/cat.10038.jpg
#   inflating: data/dogscatsredux/train/cat.10039.jpg
#   inflating: data/dogscatsredux/train/cat.1004.jpg
#   inflating: data/dogscatsredux/train/cat.10040.jpg
#   inflating: data/dogscatsredux/train/cat.10041.jpg
#   inflating: data/dogscatsredux/train/cat.10042.jpg
#   inflating: data/dogscatsredux/train/cat.10043.jpg
#   inflating: data/dogscatsredux/train/cat.10044.jpg
#   inflating: data/dogscatsredux/train/cat.10045.jpg
#   inflating: data/dogscatsredux/train/cat.10046.jpg
#   inflating: data/dogscatsredux/train/cat.10047.jpg
#   inflating: data/dogscatsredux/train/cat.10048.jpg
#   inflating: data/dogscatsredux/train/cat.10049.jpg
#   inflating: data/dogscatsredux/train/cat.1005.jpg
#   inflating: data/dogscatsredux/train/cat.10050.jpg
#   inflating: data/dogscatsredux/train/cat.10051.jpg
#   inflating: data/dogscatsredux/train/cat.10052.jpg
#   inflating: data/dogscatsredux/train/cat.10053.jpg
#   inflating: data/dogscatsredux/train/cat.10054.jpg
#   inflating: data/dogscatsredux/train/cat.10055.jpg
#   inflating: data/dogscatsredux/train/cat.10056.jpg
#   inflating: data/dogscatsredux/train/cat.10057.jpg
#   inflating: data/dogscatsredux/train/cat.10058.jpg
#   inflating: data/dogscatsredux/train/cat.10059.jpg
#   inflating: data/dogscatsredux/train/cat.1006.jpg
#   inflating: data/dogscatsredux/train/cat.10060.jpg
#   inflating: data/dogscatsredux/train/cat.10061.jpg
#   inflating: data/dogscatsredux/train/cat.10062.jpg
#   inflating: data/dogscatsredux/train/cat.10063.jpg
#   inflating: data/dogscatsredux/train/cat.10064.jpg
#   inflating: data/dogscatsredux/train/cat.10065.jpg
#   inflating: data/dogscatsredux/train/cat.10066.jpg
#   inflating: data/dogscatsredux/train/cat.10067.jpg
#   inflating: data/dogscatsredux/train/cat.10068.jpg
#   inflating: data/dogscatsredux/train/cat.10069.jpg
#   inflating: data/dogscatsredux/train/cat.1007.jpg
#   inflating: data/dogscatsredux/train/cat.10070.jpg
#   inflating: data/dogscatsredux/train/cat.10071.jpg
#   inflating: data/dogscatsredux/train/cat.10072.jpg
#   inflating: data/dogscatsredux/train/cat.10073.jpg
#   inflating: data/dogscatsredux/train/cat.10074.jpg
#   inflating: data/dogscatsredux/train/cat.10075.jpg
#   inflating: data/dogscatsredux/train/cat.10076.jpg
#   inflating: data/dogscatsredux/train/cat.10077.jpg
#   inflating: data/dogscatsredux/train/cat.10078.jpg
#   inflating: data/dogscatsredux/train/cat.10079.jpg
#   inflating: data/dogscatsredux/train/cat.1008.jpg
#   inflating: data/dogscatsredux/train/cat.10080.jpg
#   inflating: data/dogscatsredux/train/cat.10081.jpg
#   inflating: data/dogscatsredux/train/cat.10082.jpg
#   inflating: data/dogscatsredux/train/cat.10083.jpg
#   inflating: data/dogscatsredux/train/cat.10084.jpg
#   inflating: data/dogscatsredux/train/cat.10085.jpg
#   inflating: data/dogscatsredux/train/cat.10086.jpg
#   inflating: data/dogscatsredux/train/cat.10087.jpg
#   inflating: data/dogscatsredux/train/cat.10088.jpg
#   inflating: data/dogscatsredux/train/cat.10089.jpg
#   inflating: data/dogscatsredux/train/cat.1009.jpg
#   inflating: data/dogscatsredux/train/cat.10090.jpg
#   inflating: data/dogscatsredux/train/cat.10091.jpg
#   inflating: data/dogscatsredux/train/cat.10092.jpg
#   inflating: data/dogscatsredux/train/cat.10093.jpg
#   inflating: data/dogscatsredux/train/cat.10094.jpg
#   inflating: data/dogscatsredux/train/cat.10095.jpg
#   inflating: data/dogscatsredux/train/cat.10096.jpg
#   inflating: data/dogscatsredux/train/cat.10097.jpg
#   inflating: data/dogscatsredux/train/cat.10098.jpg
#   inflating: data/dogscatsredux/train/cat.10099.jpg
#   inflating: data/dogscatsredux/train/cat.101.jpg
#   inflating: data/dogscatsredux/train/cat.1010.jpg
#   inflating: data/dogscatsredux/train/cat.10100.jpg
#   inflating: data/dogscatsredux/train/cat.10101.jpg
#   inflating: data/dogscatsredux/train/cat.10102.jpg
#   inflating: data/dogscatsredux/train/cat.10103.jpg
#   inflating: data/dogscatsredux/train/cat.10104.jpg
#   inflating: data/dogscatsredux/train/cat.10105.jpg
#   inflating: data/dogscatsredux/train/cat.10106.jpg
#   inflating: data/dogscatsredux/train/cat.10107.jpg
#   inflating: data/dogscatsredux/train/cat.10108.jpg
#   inflating: data/dogscatsredux/train/cat.10109.jpg
#   inflating: data/dogscatsredux/train/cat.1011.jpg
#   inflating: data/dogscatsredux/train/cat.10110.jpg
#   inflating: data/dogscatsredux/train/cat.10111.jpg
#   inflating: data/dogscatsredux/train/cat.10112.jpg
#   inflating: data/dogscatsredux/train/cat.10113.jpg
#   inflating: data/dogscatsredux/train/cat.10114.jpg
#   inflating: data/dogscatsredux/train/cat.10115.jpg
#   inflating: data/dogscatsredux/train/cat.10116.jpg
#   inflating: data/dogscatsredux/train/cat.10117.jpg
#   inflating: data/dogscatsredux/train/cat.10118.jpg
#   inflating: data/dogscatsredux/train/cat.10119.jpg
#   inflating: data/dogscatsredux/train/cat.1012.jpg
#   inflating: data/dogscatsredux/train/cat.10120.jpg
#   inflating: data/dogscatsredux/train/cat.10121.jpg
#   inflating: data/dogscatsredux/train/cat.10122.jpg
#   inflating: data/dogscatsredux/train/cat.10123.jpg
#   inflating: data/dogscatsredux/train/cat.10124.jpg
#   inflating: data/dogscatsredux/train/cat.10125.jpg
#   inflating: data/dogscatsredux/train/cat.10126.jpg
#   inflating: data/dogscatsredux/train/cat.10127.jpg
#   inflating: data/dogscatsredux/train/cat.10128.jpg
#   inflating: data/dogscatsredux/train/cat.10129.jpg
#   inflating: data/dogscatsredux/train/cat.1013.jpg
#   inflating: data/dogscatsredux/train/cat.10130.jpg
#   inflating: data/dogscatsredux/train/cat.10131.jpg
#   inflating: data/dogscatsredux/train/cat.10132.jpg
#   inflating: data/dogscatsredux/train/cat.10133.jpg
#   inflating: data/dogscatsredux/train/cat.10134.jpg
#   inflating: data/dogscatsredux/train/cat.10135.jpg
#   inflating: data/dogscatsredux/train/cat.10136.jpg
#   inflating: data/dogscatsredux/train/cat.10137.jpg
#   inflating: data/dogscatsredux/train/cat.10138.jpg
#   inflating: data/dogscatsredux/train/cat.10139.jpg
#   inflating: data/dogscatsredux/train/cat.1014.jpg
#   inflating: data/dogscatsredux/train/cat.10140.jpg
#   inflating: data/dogscatsredux/train/cat.10141.jpg
#   inflating: data/dogscatsredux/train/cat.10142.jpg
#   inflating: data/dogscatsredux/train/cat.10143.jpg
#   inflating: data/dogscatsredux/train/cat.10144.jpg
#   inflating: data/dogscatsredux/train/cat.10145.jpg
#   inflating: data/dogscatsredux/train/cat.10146.jpg
#   inflating: data/dogscatsredux/train/cat.10147.jpg
#   inflating: data/dogscatsredux/train/cat.10148.jpg
#   inflating: data/dogscatsredux/train/cat.10149.jpg
#   inflating: data/dogscatsredux/train/cat.1015.jpg
#   inflating: data/dogscatsredux/train/cat.10150.jpg
#   inflating: data/dogscatsredux/train/cat.10151.jpg
#   inflating: data/dogscatsredux/train/cat.10152.jpg
#   inflating: data/dogscatsredux/train/cat.10153.jpg
#   inflating: data/dogscatsredux/train/cat.10154.jpg
#   inflating: data/dogscatsredux/train/cat.10155.jpg
#   inflating: data/dogscatsredux/train/cat.10156.jpg
#   inflating: data/dogscatsredux/train/cat.10157.jpg
#   inflating: data/dogscatsredux/train/cat.10158.jpg
#   inflating: data/dogscatsredux/train/cat.10159.jpg
#   inflating: data/dogscatsredux/train/cat.1016.jpg
#   inflating: data/dogscatsredux/train/cat.10160.jpg
#   inflating: data/dogscatsredux/train/cat.10161.jpg
#   inflating: data/dogscatsredux/train/cat.10162.jpg
#   inflating: data/dogscatsredux/train/cat.10163.jpg
#   inflating: data/dogscatsredux/train/cat.10164.jpg
#   inflating: data/dogscatsredux/train/cat.10165.jpg
#   inflating: data/dogscatsredux/train/cat.10166.jpg
#   inflating: data/dogscatsredux/train/cat.10167.jpg
#   inflating: data/dogscatsredux/train/cat.10168.jpg
#   inflating: data/dogscatsredux/train/cat.10169.jpg
#   inflating: data/dogscatsredux/train/cat.1017.jpg
#   inflating: data/dogscatsredux/train/cat.10170.jpg
#   inflating: data/dogscatsredux/train/cat.10171.jpg
#   inflating: data/dogscatsredux/train/cat.10172.jpg
#   inflating: data/dogscatsredux/train/cat.10173.jpg
#   inflating: data/dogscatsredux/train/cat.10174.jpg
#   inflating: data/dogscatsredux/train/cat.10175.jpg
#   inflating: data/dogscatsredux/train/cat.10176.jpg
#   inflating: data/dogscatsredux/train/cat.10177.jpg
#   inflating: data/dogscatsredux/train/cat.10178.jpg
#   inflating: data/dogscatsredux/train/cat.10179.jpg
#   inflating: data/dogscatsredux/train/cat.1018.jpg
#   inflating: data/dogscatsredux/train/cat.10180.jpg
#   inflating: data/dogscatsredux/train/cat.10181.jpg
#   inflating: data/dogscatsredux/train/cat.10182.jpg
#   inflating: data/dogscatsredux/train/cat.10183.jpg
#   inflating: data/dogscatsredux/train/cat.10184.jpg
#   inflating: data/dogscatsredux/train/cat.10185.jpg
#   inflating: data/dogscatsredux/train/cat.10186.jpg
#   inflating: data/dogscatsredux/train/cat.10187.jpg
#   inflating: data/dogscatsredux/train/cat.10188.jpg
#   inflating: data/dogscatsredux/train/cat.10189.jpg
#   inflating: data/dogscatsredux/train/cat.1019.jpg
#   inflating: data/dogscatsredux/train/cat.10190.jpg
#   inflating: data/dogscatsredux/train/cat.10191.jpg
#   inflating: data/dogscatsredux/train/cat.10192.jpg
#   inflating: data/dogscatsredux/train/cat.10193.jpg
#   inflating: data/dogscatsredux/train/cat.10194.jpg
#   inflating: data/dogscatsredux/train/cat.10195.jpg
#   inflating: data/dogscatsredux/train/cat.10196.jpg
#   inflating: data/dogscatsredux/train/cat.10197.jpg
#   inflating: data/dogscatsredux/train/cat.10198.jpg
#   inflating: data/dogscatsredux/train/cat.10199.jpg
#   inflating: data/dogscatsredux/train/cat.102.jpg
#   inflating: data/dogscatsredux/train/cat.1020.jpg
#   inflating: data/dogscatsredux/train/cat.10200.jpg
#   inflating: data/dogscatsredux/train/cat.10201.jpg
#   inflating: data/dogscatsredux/train/cat.10202.jpg
#   inflating: data/dogscatsredux/train/cat.10203.jpg
#   inflating: data/dogscatsredux/train/cat.10204.jpg
#   inflating: data/dogscatsredux/train/cat.10205.jpg
#   inflating: data/dogscatsredux/train/cat.10206.jpg
#   inflating: data/dogscatsredux/train/cat.10207.jpg
#   inflating: data/dogscatsredux/train/cat.10208.jpg
#   inflating: data/dogscatsredux/train/cat.10209.jpg
#   inflating: data/dogscatsredux/train/cat.1021.jpg
#   inflating: data/dogscatsredux/train/cat.10210.jpg
#   inflating: data/dogscatsredux/train/cat.10211.jpg
#   inflating: data/dogscatsredux/train/cat.10212.jpg
#   inflating: data/dogscatsredux/train/cat.10213.jpg
#   inflating: data/dogscatsredux/train/cat.10214.jpg
#   inflating: data/dogscatsredux/train/cat.10215.jpg
#   inflating: data/dogscatsredux/train/cat.10216.jpg
#   inflating: data/dogscatsredux/train/cat.10217.jpg
#   inflating: data/dogscatsredux/train/cat.10218.jpg
#   inflating: data/dogscatsredux/train/cat.10219.jpg
#   inflating: data/dogscatsredux/train/cat.1022.jpg
#   inflating: data/dogscatsredux/train/cat.10220.jpg
#   inflating: data/dogscatsredux/train/cat.10221.jpg
#   inflating: data/dogscatsredux/train/cat.10222.jpg
#   inflating: data/dogscatsredux/train/cat.10223.jpg
#   inflating: data/dogscatsredux/train/cat.10224.jpg
#   inflating: data/dogscatsredux/train/cat.10225.jpg
#   inflating: data/dogscatsredux/train/cat.10226.jpg
#   inflating: data/dogscatsredux/train/cat.10227.jpg
#   inflating: data/dogscatsredux/train/cat.10228.jpg
#   inflating: data/dogscatsredux/train/cat.10229.jpg
#   inflating: data/dogscatsredux/train/cat.1023.jpg
#   inflating: data/dogscatsredux/train/cat.10230.jpg
#   inflating: data/dogscatsredux/train/cat.10231.jpg
#   inflating: data/dogscatsredux/train/cat.10232.jpg
#   inflating: data/dogscatsredux/train/cat.10233.jpg
#   inflating: data/dogscatsredux/train/cat.10234.jpg
#   inflating: data/dogscatsredux/train/cat.10235.jpg
#   inflating: data/dogscatsredux/train/cat.10236.jpg
#   inflating: data/dogscatsredux/train/cat.10237.jpg
#   inflating: data/dogscatsredux/train/cat.10238.jpg
#   inflating: data/dogscatsredux/train/cat.10239.jpg
#   inflating: data/dogscatsredux/train/cat.1024.jpg
#   inflating: data/dogscatsredux/train/cat.10240.jpg
#   inflating: data/dogscatsredux/train/cat.10241.jpg
#   inflating: data/dogscatsredux/train/cat.10242.jpg
#   inflating: data/dogscatsredux/train/cat.10243.jpg
#   inflating: data/dogscatsredux/train/cat.10244.jpg
#   inflating: data/dogscatsredux/train/cat.10245.jpg
#   inflating: data/dogscatsredux/train/cat.10246.jpg
#   inflating: data/dogscatsredux/train/cat.10247.jpg
#   inflating: data/dogscatsredux/train/cat.10248.jpg
#   inflating: data/dogscatsredux/train/cat.10249.jpg
#   inflating: data/dogscatsredux/train/cat.1025.jpg
#   inflating: data/dogscatsredux/train/cat.10250.jpg
#   inflating: data/dogscatsredux/train/cat.10251.jpg
#   inflating: data/dogscatsredux/train/cat.10252.jpg
#   inflating: data/dogscatsredux/train/cat.10253.jpg
#   inflating: data/dogscatsredux/train/cat.10254.jpg
#   inflating: data/dogscatsredux/train/cat.10255.jpg
#   inflating: data/dogscatsredux/train/cat.10256.jpg
#   inflating: data/dogscatsredux/train/cat.10257.jpg
#   inflating: data/dogscatsredux/train/cat.10258.jpg
#   inflating: data/dogscatsredux/train/cat.10259.jpg
#   inflating: data/dogscatsredux/train/cat.1026.jpg
#   inflating: data/dogscatsredux/train/cat.10260.jpg
#   inflating: data/dogscatsredux/train/cat.10261.jpg
#   inflating: data/dogscatsredux/train/cat.10262.jpg
#   inflating: data/dogscatsredux/train/cat.10263.jpg
#   inflating: data/dogscatsredux/train/cat.10264.jpg
#   inflating: data/dogscatsredux/train/cat.10265.jpg
#   inflating: data/dogscatsredux/train/cat.10266.jpg
#   inflating: data/dogscatsredux/train/cat.10267.jpg
#   inflating: data/dogscatsredux/train/cat.10268.jpg
#   inflating: data/dogscatsredux/train/cat.10269.jpg
#   inflating: data/dogscatsredux/train/cat.1027.jpg
#   inflating: data/dogscatsredux/train/cat.10270.jpg
#   inflating: data/dogscatsredux/train/cat.10271.jpg
#   inflating: data/dogscatsredux/train/cat.10272.jpg
#   inflating: data/dogscatsredux/train/cat.10273.jpg
#   inflating: data/dogscatsredux/train/cat.10274.jpg
#   inflating: data/dogscatsredux/train/cat.10275.jpg
#   inflating: data/dogscatsredux/train/cat.10276.jpg
#   inflating: data/dogscatsredux/train/cat.10277.jpg
#   inflating: data/dogscatsredux/train/cat.10278.jpg
#   inflating: data/dogscatsredux/train/cat.10279.jpg
#   inflating: data/dogscatsredux/train/cat.1028.jpg
#   inflating: data/dogscatsredux/train/cat.10280.jpg
#   inflating: data/dogscatsredux/train/cat.10281.jpg
#   inflating: data/dogscatsredux/train/cat.10282.jpg
#   inflating: data/dogscatsredux/train/cat.10283.jpg
#   inflating: data/dogscatsredux/train/cat.10284.jpg
#   inflating: data/dogscatsredux/train/cat.10285.jpg
#   inflating: data/dogscatsredux/train/cat.10286.jpg
#   inflating: data/dogscatsredux/train/cat.10287.jpg
#   inflating: data/dogscatsredux/train/cat.10288.jpg
#   inflating: data/dogscatsredux/train/cat.10289.jpg
#   inflating: data/dogscatsredux/train/cat.1029.jpg
#   inflating: data/dogscatsredux/train/cat.10290.jpg
#   inflating: data/dogscatsredux/train/cat.10291.jpg
#   inflating: data/dogscatsredux/train/cat.10292.jpg
#   inflating: data/dogscatsredux/train/cat.10293.jpg
#   inflating: data/dogscatsredux/train/cat.10294.jpg
#   inflating: data/dogscatsredux/train/cat.10295.jpg
#   inflating: data/dogscatsredux/train/cat.10296.jpg
#   inflating: data/dogscatsredux/train/cat.10297.jpg
#   inflating: data/dogscatsredux/train/cat.10298.jpg
#   inflating: data/dogscatsredux/train/cat.10299.jpg
#   inflating: data/dogscatsredux/train/cat.103.jpg
#   inflating: data/dogscatsredux/train/cat.1030.jpg
#   inflating: data/dogscatsredux/train/cat.10300.jpg
#   inflating: data/dogscatsredux/train/cat.10301.jpg
#   inflating: data/dogscatsredux/train/cat.10302.jpg
#   inflating: data/dogscatsredux/train/cat.10303.jpg
#   inflating: data/dogscatsredux/train/cat.10304.jpg
#   inflating: data/dogscatsredux/train/cat.10305.jpg
#   inflating: data/dogscatsredux/train/cat.10306.jpg
#   inflating: data/dogscatsredux/train/cat.10307.jpg
#   inflating: data/dogscatsredux/train/cat.10308.jpg
#   inflating: data/dogscatsredux/train/cat.10309.jpg
#   inflating: data/dogscatsredux/train/cat.1031.jpg
#   inflating: data/dogscatsredux/train/cat.10310.jpg
#   inflating: data/dogscatsredux/train/cat.10311.jpg
#   inflating: data/dogscatsredux/train/cat.10312.jpg
#   inflating: data/dogscatsredux/train/cat.10313.jpg
#   inflating: data/dogscatsredux/train/cat.10314.jpg
#   inflating: data/dogscatsredux/train/cat.10315.jpg
#   inflating: data/dogscatsredux/train/cat.10316.jpg
#   inflating: data/dogscatsredux/train/cat.10317.jpg
#   inflating: data/dogscatsredux/train/cat.10318.jpg
#   inflating: data/dogscatsredux/train/cat.10319.jpg
#   inflating: data/dogscatsredux/train/cat.1032.jpg
#   inflating: data/dogscatsredux/train/cat.10320.jpg
#   inflating: data/dogscatsredux/train/cat.10321.jpg
#   inflating: data/dogscatsredux/train/cat.10322.jpg
#   inflating: data/dogscatsredux/train/cat.10323.jpg
#   inflating: data/dogscatsredux/train/cat.10324.jpg
#   inflating: data/dogscatsredux/train/cat.10325.jpg
#   inflating: data/dogscatsredux/train/cat.10326.jpg
#   inflating: data/dogscatsredux/train/cat.10327.jpg
#   inflating: data/dogscatsredux/train/cat.10328.jpg
#   inflating: data/dogscatsredux/train/cat.10329.jpg
#   inflating: data/dogscatsredux/train/cat.1033.jpg
#   inflating: data/dogscatsredux/train/cat.10330.jpg
#   inflating: data/dogscatsredux/train/cat.10331.jpg
#   inflating: data/dogscatsredux/train/cat.10332.jpg
#   inflating: data/dogscatsredux/train/cat.10333.jpg
#   inflating: data/dogscatsredux/train/cat.10334.jpg
#   inflating: data/dogscatsredux/train/cat.10335.jpg
#   inflating: data/dogscatsredux/train/cat.10336.jpg
#   inflating: data/dogscatsredux/train/cat.10337.jpg
#   inflating: data/dogscatsredux/train/cat.10338.jpg
#   inflating: data/dogscatsredux/train/cat.10339.jpg
#   inflating: data/dogscatsredux/train/cat.1034.jpg
#   inflating: data/dogscatsredux/train/cat.10340.jpg
#   inflating: data/dogscatsredux/train/cat.10341.jpg
#   inflating: data/dogscatsredux/train/cat.10342.jpg
#   inflating: data/dogscatsredux/train/cat.10343.jpg
#   inflating: data/dogscatsredux/train/cat.10344.jpg
#   inflating: data/dogscatsredux/train/cat.10345.jpg
#   inflating: data/dogscatsredux/train/cat.10346.jpg
#   inflating: data/dogscatsredux/train/cat.10347.jpg
#   inflating: data/dogscatsredux/train/cat.10348.jpg
#   inflating: data/dogscatsredux/train/cat.10349.jpg
#   inflating: data/dogscatsredux/train/cat.1035.jpg
#   inflating: data/dogscatsredux/train/cat.10350.jpg
#   inflating: data/dogscatsredux/train/cat.10351.jpg
#   inflating: data/dogscatsredux/train/cat.10352.jpg
#   inflating: data/dogscatsredux/train/cat.10353.jpg
#   inflating: data/dogscatsredux/train/cat.10354.jpg
#   inflating: data/dogscatsredux/train/cat.10355.jpg
#   inflating: data/dogscatsredux/train/cat.10356.jpg
#   inflating: data/dogscatsredux/train/cat.10357.jpg
#   inflating: data/dogscatsredux/train/cat.10358.jpg
#   inflating: data/dogscatsredux/train/cat.10359.jpg
#   inflating: data/dogscatsredux/train/cat.1036.jpg
#   inflating: data/dogscatsredux/train/cat.10360.jpg
#   inflating: data/dogscatsredux/train/cat.10361.jpg
#   inflating: data/dogscatsredux/train/cat.10362.jpg
#   inflating: data/dogscatsredux/train/cat.10363.jpg
#   inflating: data/dogscatsredux/train/cat.10364.jpg
#   inflating: data/dogscatsredux/train/cat.10365.jpg
#   inflating: data/dogscatsredux/train/cat.10366.jpg
#   inflating: data/dogscatsredux/train/cat.10367.jpg
#   inflating: data/dogscatsredux/train/cat.10368.jpg
#   inflating: data/dogscatsredux/train/cat.10369.jpg
#   inflating: data/dogscatsredux/train/cat.1037.jpg
#   inflating: data/dogscatsredux/train/cat.10370.jpg
#   inflating: data/dogscatsredux/train/cat.10371.jpg
#   inflating: data/dogscatsredux/train/cat.10372.jpg
#   inflating: data/dogscatsredux/train/cat.10373.jpg
#   inflating: data/dogscatsredux/train/cat.10374.jpg
#   inflating: data/dogscatsredux/train/cat.10375.jpg
#   inflating: data/dogscatsredux/train/cat.10376.jpg
#   inflating: data/dogscatsredux/train/cat.10377.jpg
#   inflating: data/dogscatsredux/train/cat.10378.jpg
#   inflating: data/dogscatsredux/train/cat.10379.jpg
#   inflating: data/dogscatsredux/train/cat.1038.jpg
#   inflating: data/dogscatsredux/train/cat.10380.jpg
#   inflating: data/dogscatsredux/train/cat.10381.jpg
#   inflating: data/dogscatsredux/train/cat.10382.jpg
#   inflating: data/dogscatsredux/train/cat.10383.jpg
#   inflating: data/dogscatsredux/train/cat.10384.jpg
#   inflating: data/dogscatsredux/train/cat.10385.jpg
#   inflating: data/dogscatsredux/train/cat.10386.jpg
#   inflating: data/dogscatsredux/train/cat.10387.jpg
#   inflating: data/dogscatsredux/train/cat.10388.jpg
#   inflating: data/dogscatsredux/train/cat.10389.jpg
#   inflating: data/dogscatsredux/train/cat.1039.jpg
#   inflating: data/dogscatsredux/train/cat.10390.jpg
#   inflating: data/dogscatsredux/train/cat.10391.jpg
#   inflating: data/dogscatsredux/train/cat.10392.jpg
#   inflating: data/dogscatsredux/train/cat.10393.jpg
#   inflating: data/dogscatsredux/train/cat.10394.jpg
#   inflating: data/dogscatsredux/train/cat.10395.jpg
#   inflating: data/dogscatsredux/train/cat.10396.jpg
#   inflating: data/dogscatsredux/train/cat.10397.jpg
#   inflating: data/dogscatsredux/train/cat.10398.jpg
#   inflating: data/dogscatsredux/train/cat.10399.jpg
#   inflating: data/dogscatsredux/train/cat.104.jpg
#   inflating: data/dogscatsredux/train/cat.1040.jpg
#   inflating: data/dogscatsredux/train/cat.10400.jpg
#   inflating: data/dogscatsredux/train/cat.10401.jpg
#   inflating: data/dogscatsredux/train/cat.10402.jpg
#   inflating: data/dogscatsredux/train/cat.10403.jpg
#   inflating: data/dogscatsredux/train/cat.10404.jpg
#   inflating: data/dogscatsredux/train/cat.10405.jpg
#   inflating: data/dogscatsredux/train/cat.10406.jpg
#   inflating: data/dogscatsredux/train/cat.10407.jpg
#   inflating: data/dogscatsredux/train/cat.10408.jpg
#   inflating: data/dogscatsredux/train/cat.10409.jpg
#   inflating: data/dogscatsredux/train/cat.1041.jpg
#   inflating: data/dogscatsredux/train/cat.10410.jpg
#   inflating: data/dogscatsredux/train/cat.10411.jpg
#   inflating: data/dogscatsredux/train/cat.10412.jpg
#   inflating: data/dogscatsredux/train/cat.10413.jpg
#   inflating: data/dogscatsredux/train/cat.10414.jpg
#   inflating: data/dogscatsredux/train/cat.10415.jpg
#   inflating: data/dogscatsredux/train/cat.10416.jpg
#   inflating: data/dogscatsredux/train/cat.10417.jpg
#   inflating: data/dogscatsredux/train/cat.10418.jpg
#   inflating: data/dogscatsredux/train/cat.10419.jpg
#   inflating: data/dogscatsredux/train/cat.1042.jpg
#   inflating: data/dogscatsredux/train/cat.10420.jpg
#   inflating: data/dogscatsredux/train/cat.10421.jpg
#   inflating: data/dogscatsredux/train/cat.10422.jpg
#   inflating: data/dogscatsredux/train/cat.10423.jpg
#   inflating: data/dogscatsredux/train/cat.10424.jpg
#   inflating: data/dogscatsredux/train/cat.10425.jpg
#   inflating: data/dogscatsredux/train/cat.10426.jpg
#   inflating: data/dogscatsredux/train/cat.10427.jpg
#   inflating: data/dogscatsredux/train/cat.10428.jpg
#   inflating: data/dogscatsredux/train/cat.10429.jpg
#   inflating: data/dogscatsredux/train/cat.1043.jpg
#   inflating: data/dogscatsredux/train/cat.10430.jpg
#   inflating: data/dogscatsredux/train/cat.10431.jpg
#   inflating: data/dogscatsredux/train/cat.10432.jpg
#   inflating: data/dogscatsredux/train/cat.10433.jpg
#   inflating: data/dogscatsredux/train/cat.10434.jpg
#   inflating: data/dogscatsredux/train/cat.10435.jpg
#   inflating: data/dogscatsredux/train/cat.10436.jpg
#   inflating: data/dogscatsredux/train/cat.10437.jpg
#   inflating: data/dogscatsredux/train/cat.10438.jpg
#   inflating: data/dogscatsredux/train/cat.10439.jpg
#   inflating: data/dogscatsredux/train/cat.1044.jpg
#   inflating: data/dogscatsredux/train/cat.10440.jpg
#   inflating: data/dogscatsredux/train/cat.10441.jpg
#   inflating: data/dogscatsredux/train/cat.10442.jpg
#   inflating: data/dogscatsredux/train/cat.10443.jpg
#   inflating: data/dogscatsredux/train/cat.10444.jpg
#   inflating: data/dogscatsredux/train/cat.10445.jpg
#   inflating: data/dogscatsredux/train/cat.10446.jpg
#   inflating: data/dogscatsredux/train/cat.10447.jpg
#   inflating: data/dogscatsredux/train/cat.10448.jpg
#   inflating: data/dogscatsredux/train/cat.10449.jpg
#   inflating: data/dogscatsredux/train/cat.1045.jpg
#   inflating: data/dogscatsredux/train/cat.10450.jpg
#   inflating: data/dogscatsredux/train/cat.10451.jpg
#   inflating: data/dogscatsredux/train/cat.10452.jpg
#   inflating: data/dogscatsredux/train/cat.10453.jpg
#   inflating: data/dogscatsredux/train/cat.10454.jpg
#   inflating: data/dogscatsredux/train/cat.10455.jpg
#   inflating: data/dogscatsredux/train/cat.10456.jpg
#   inflating: data/dogscatsredux/train/cat.10457.jpg
#   inflating: data/dogscatsredux/train/cat.10458.jpg
#   inflating: data/dogscatsredux/train/cat.10459.jpg
#   inflating: data/dogscatsredux/train/cat.1046.jpg
#   inflating: data/dogscatsredux/train/cat.10460.jpg
#   inflating: data/dogscatsredux/train/cat.10461.jpg
#   inflating: data/dogscatsredux/train/cat.10462.jpg
#   inflating: data/dogscatsredux/train/cat.10463.jpg
#   inflating: data/dogscatsredux/train/cat.10464.jpg
#   inflating: data/dogscatsredux/train/cat.10465.jpg
#   inflating: data/dogscatsredux/train/cat.10466.jpg
#   inflating: data/dogscatsredux/train/cat.10467.jpg
#   inflating: data/dogscatsredux/train/cat.10468.jpg
#   inflating: data/dogscatsredux/train/cat.10469.jpg
#   inflating: data/dogscatsredux/train/cat.1047.jpg
#   inflating: data/dogscatsredux/train/cat.10470.jpg
#   inflating: data/dogscatsredux/train/cat.10471.jpg
#   inflating: data/dogscatsredux/train/cat.10472.jpg
#   inflating: data/dogscatsredux/train/cat.10473.jpg
#   inflating: data/dogscatsredux/train/cat.10474.jpg
#   inflating: data/dogscatsredux/train/cat.10475.jpg
#   inflating: data/dogscatsredux/train/cat.10476.jpg
#   inflating: data/dogscatsredux/train/cat.10477.jpg
#   inflating: data/dogscatsredux/train/cat.10478.jpg
#   inflating: data/dogscatsredux/train/cat.10479.jpg
#   inflating: data/dogscatsredux/train/cat.1048.jpg
#   inflating: data/dogscatsredux/train/cat.10480.jpg
#   inflating: data/dogscatsredux/train/cat.10481.jpg
#   inflating: data/dogscatsredux/train/cat.10482.jpg
#   inflating: data/dogscatsredux/train/cat.10483.jpg
#   inflating: data/dogscatsredux/train/cat.10484.jpg
#   inflating: data/dogscatsredux/train/cat.10485.jpg
#   inflating: data/dogscatsredux/train/cat.10486.jpg
#   inflating: data/dogscatsredux/train/cat.10487.jpg
#   inflating: data/dogscatsredux/train/cat.10488.jpg
#   inflating: data/dogscatsredux/train/cat.10489.jpg
#   inflating: data/dogscatsredux/train/cat.1049.jpg
#   inflating: data/dogscatsredux/train/cat.10490.jpg
#   inflating: data/dogscatsredux/train/cat.10491.jpg
#   inflating: data/dogscatsredux/train/cat.10492.jpg
#   inflating: data/dogscatsredux/train/cat.10493.jpg
#   inflating: data/dogscatsredux/train/cat.10494.jpg
#   inflating: data/dogscatsredux/train/cat.10495.jpg
#   inflating: data/dogscatsredux/train/cat.10496.jpg
#   inflating: data/dogscatsredux/train/cat.10497.jpg
#   inflating: data/dogscatsredux/train/cat.10498.jpg
#   inflating: data/dogscatsredux/train/cat.10499.jpg
#   inflating: data/dogscatsredux/train/cat.105.jpg
#   inflating: data/dogscatsredux/train/cat.1050.jpg
#   inflating: data/dogscatsredux/train/cat.10500.jpg
#   inflating: data/dogscatsredux/train/cat.10501.jpg
#   inflating: data/dogscatsredux/train/cat.10502.jpg
#   inflating: data/dogscatsredux/train/cat.10503.jpg
#   inflating: data/dogscatsredux/train/cat.10504.jpg
#   inflating: data/dogscatsredux/train/cat.10505.jpg
#   inflating: data/dogscatsredux/train/cat.10506.jpg
#   inflating: data/dogscatsredux/train/cat.10507.jpg
#   inflating: data/dogscatsredux/train/cat.10508.jpg
#   inflating: data/dogscatsredux/train/cat.10509.jpg
#   inflating: data/dogscatsredux/train/cat.1051.jpg
#   inflating: data/dogscatsredux/train/cat.10510.jpg
#   inflating: data/dogscatsredux/train/cat.10511.jpg
#   inflating: data/dogscatsredux/train/cat.10512.jpg
#   inflating: data/dogscatsredux/train/cat.10513.jpg
#   inflating: data/dogscatsredux/train/cat.10514.jpg
#   inflating: data/dogscatsredux/train/cat.10515.jpg
#   inflating: data/dogscatsredux/train/cat.10516.jpg
#   inflating: data/dogscatsredux/train/cat.10517.jpg
#   inflating: data/dogscatsredux/train/cat.10518.jpg
#   inflating: data/dogscatsredux/train/cat.10519.jpg
#   inflating: data/dogscatsredux/train/cat.1052.jpg
#   inflating: data/dogscatsredux/train/cat.10520.jpg
#   inflating: data/dogscatsredux/train/cat.10521.jpg
#   inflating: data/dogscatsredux/train/cat.10522.jpg
#   inflating: data/dogscatsredux/train/cat.10523.jpg
#   inflating: data/dogscatsredux/train/cat.10524.jpg
#   inflating: data/dogscatsredux/train/cat.10525.jpg
#   inflating: data/dogscatsredux/train/cat.10526.jpg
#   inflating: data/dogscatsredux/train/cat.10527.jpg
#   inflating: data/dogscatsredux/train/cat.10528.jpg
#   inflating: data/dogscatsredux/train/cat.10529.jpg
#   inflating: data/dogscatsredux/train/cat.1053.jpg
#   inflating: data/dogscatsredux/train/cat.10530.jpg
#   inflating: data/dogscatsredux/train/cat.10531.jpg
#   inflating: data/dogscatsredux/train/cat.10532.jpg
#   inflating: data/dogscatsredux/train/cat.10533.jpg
#   inflating: data/dogscatsredux/train/cat.10534.jpg
#   inflating: data/dogscatsredux/train/cat.10535.jpg
#   inflating: data/dogscatsredux/train/cat.10536.jpg
#   inflating: data/dogscatsredux/train/cat.10537.jpg
#   inflating: data/dogscatsredux/train/cat.10538.jpg
#   inflating: data/dogscatsredux/train/cat.10539.jpg
#   inflating: data/dogscatsredux/train/cat.1054.jpg
#   inflating: data/dogscatsredux/train/cat.10540.jpg
#   inflating: data/dogscatsredux/train/cat.10541.jpg
#   inflating: data/dogscatsredux/train/cat.10542.jpg
#   inflating: data/dogscatsredux/train/cat.10543.jpg
#   inflating: data/dogscatsredux/train/cat.10544.jpg
#   inflating: data/dogscatsredux/train/cat.10545.jpg
#   inflating: data/dogscatsredux/train/cat.10546.jpg
#   inflating: data/dogscatsredux/train/cat.10547.jpg
#   inflating: data/dogscatsredux/train/cat.10548.jpg
#   inflating: data/dogscatsredux/train/cat.10549.jpg
#   inflating: data/dogscatsredux/train/cat.1055.jpg
#   inflating: data/dogscatsredux/train/cat.10550.jpg
#   inflating: data/dogscatsredux/train/cat.10551.jpg
#   inflating: data/dogscatsredux/train/cat.10552.jpg
#   inflating: data/dogscatsredux/train/cat.10553.jpg
#   inflating: data/dogscatsredux/train/cat.10554.jpg
#   inflating: data/dogscatsredux/train/cat.10555.jpg
#   inflating: data/dogscatsredux/train/cat.10556.jpg
#   inflating: data/dogscatsredux/train/cat.10557.jpg
#   inflating: data/dogscatsredux/train/cat.10558.jpg
#   inflating: data/dogscatsredux/train/cat.10559.jpg
#   inflating: data/dogscatsredux/train/cat.1056.jpg
#   inflating: data/dogscatsredux/train/cat.10560.jpg
#   inflating: data/dogscatsredux/train/cat.10561.jpg
#   inflating: data/dogscatsredux/train/cat.10562.jpg
#   inflating: data/dogscatsredux/train/cat.10563.jpg
#   inflating: data/dogscatsredux/train/cat.10564.jpg
#   inflating: data/dogscatsredux/train/cat.10565.jpg
#   inflating: data/dogscatsredux/train/cat.10566.jpg
#   inflating: data/dogscatsredux/train/cat.10567.jpg
#   inflating: data/dogscatsredux/train/cat.10568.jpg
#   inflating: data/dogscatsredux/train/cat.10569.jpg
#   inflating: data/dogscatsredux/train/cat.1057.jpg
#   inflating: data/dogscatsredux/train/cat.10570.jpg
#   inflating: data/dogscatsredux/train/cat.10571.jpg
#   inflating: data/dogscatsredux/train/cat.10572.jpg
#   inflating: data/dogscatsredux/train/cat.10573.jpg
#   inflating: data/dogscatsredux/train/cat.10574.jpg
#   inflating: data/dogscatsredux/train/cat.10575.jpg
#   inflating: data/dogscatsredux/train/cat.10576.jpg
#   inflating: data/dogscatsredux/train/cat.10577.jpg
#   inflating: data/dogscatsredux/train/cat.10578.jpg
#   inflating: data/dogscatsredux/train/cat.10579.jpg
#   inflating: data/dogscatsredux/train/cat.1058.jpg
#   inflating: data/dogscatsredux/train/cat.10580.jpg
#   inflating: data/dogscatsredux/train/cat.10581.jpg
#   inflating: data/dogscatsredux/train/cat.10582.jpg
#   inflating: data/dogscatsredux/train/cat.10583.jpg
#   inflating: data/dogscatsredux/train/cat.10584.jpg
#   inflating: data/dogscatsredux/train/cat.10585.jpg
#   inflating: data/dogscatsredux/train/cat.10586.jpg
#   inflating: data/dogscatsredux/train/cat.10587.jpg
#   inflating: data/dogscatsredux/train/cat.10588.jpg
#   inflating: data/dogscatsredux/train/cat.10589.jpg
#   inflating: data/dogscatsredux/train/cat.1059.jpg
#   inflating: data/dogscatsredux/train/cat.10590.jpg
#   inflating: data/dogscatsredux/train/cat.10591.jpg
#   inflating: data/dogscatsredux/train/cat.10592.jpg
#   inflating: data/dogscatsredux/train/cat.10593.jpg
#   inflating: data/dogscatsredux/train/cat.10594.jpg
#   inflating: data/dogscatsredux/train/cat.10595.jpg
#   inflating: data/dogscatsredux/train/cat.10596.jpg
#   inflating: data/dogscatsredux/train/cat.10597.jpg
#   inflating: data/dogscatsredux/train/cat.10598.jpg
#   inflating: data/dogscatsredux/train/cat.10599.jpg
#   inflating: data/dogscatsredux/train/cat.106.jpg
#   inflating: data/dogscatsredux/train/cat.1060.jpg
#   inflating: data/dogscatsredux/train/cat.10600.jpg
#   inflating: data/dogscatsredux/train/cat.10601.jpg
#   inflating: data/dogscatsredux/train/cat.10602.jpg
#   inflating: data/dogscatsredux/train/cat.10603.jpg
#   inflating: data/dogscatsredux/train/cat.10604.jpg
#   inflating: data/dogscatsredux/train/cat.10605.jpg
#   inflating: data/dogscatsredux/train/cat.10606.jpg
#   inflating: data/dogscatsredux/train/cat.10607.jpg
#   inflating: data/dogscatsredux/train/cat.10608.jpg
#   inflating: data/dogscatsredux/train/cat.10609.jpg
#   inflating: data/dogscatsredux/train/cat.1061.jpg
#   inflating: data/dogscatsredux/train/cat.10610.jpg
#   inflating: data/dogscatsredux/train/cat.10611.jpg
#   inflating: data/dogscatsredux/train/cat.10612.jpg
#   inflating: data/dogscatsredux/train/cat.10613.jpg
#   inflating: data/dogscatsredux/train/cat.10614.jpg
#   inflating: data/dogscatsredux/train/cat.10615.jpg
#   inflating: data/dogscatsredux/train/cat.10616.jpg
#   inflating: data/dogscatsredux/train/cat.10617.jpg
#   inflating: data/dogscatsredux/train/cat.10618.jpg
#   inflating: data/dogscatsredux/train/cat.10619.jpg
#   inflating: data/dogscatsredux/train/cat.1062.jpg
#   inflating: data/dogscatsredux/train/cat.10620.jpg
#   inflating: data/dogscatsredux/train/cat.10621.jpg
#   inflating: data/dogscatsredux/train/cat.10622.jpg
#   inflating: data/dogscatsredux/train/cat.10623.jpg
#   inflating: data/dogscatsredux/train/cat.10624.jpg
#   inflating: data/dogscatsredux/train/cat.10625.jpg
#   inflating: data/dogscatsredux/train/cat.10626.jpg
#   inflating: data/dogscatsredux/train/cat.10627.jpg
#   inflating: data/dogscatsredux/train/cat.10628.jpg
#   inflating: data/dogscatsredux/train/cat.10629.jpg
#   inflating: data/dogscatsredux/train/cat.1063.jpg
#   inflating: data/dogscatsredux/train/cat.10630.jpg
#   inflating: data/dogscatsredux/train/cat.10631.jpg
#   inflating: data/dogscatsredux/train/cat.10632.jpg
#   inflating: data/dogscatsredux/train/cat.10633.jpg
#   inflating: data/dogscatsredux/train/cat.10634.jpg
#   inflating: data/dogscatsredux/train/cat.10635.jpg
#   inflating: data/dogscatsredux/train/cat.10636.jpg
#   inflating: data/dogscatsredux/train/cat.10637.jpg
#   inflating: data/dogscatsredux/train/cat.10638.jpg
#   inflating: data/dogscatsredux/train/cat.10639.jpg
#   inflating: data/dogscatsredux/train/cat.1064.jpg
#   inflating: data/dogscatsredux/train/cat.10640.jpg
#   inflating: data/dogscatsredux/train/cat.10641.jpg
#   inflating: data/dogscatsredux/train/cat.10642.jpg
#   inflating: data/dogscatsredux/train/cat.10643.jpg
#   inflating: data/dogscatsredux/train/cat.10644.jpg
#   inflating: data/dogscatsredux/train/cat.10645.jpg
#   inflating: data/dogscatsredux/train/cat.10646.jpg
#   inflating: data/dogscatsredux/train/cat.10647.jpg
#   inflating: data/dogscatsredux/train/cat.10648.jpg
#   inflating: data/dogscatsredux/train/cat.10649.jpg
#   inflating: data/dogscatsredux/train/cat.1065.jpg
#   inflating: data/dogscatsredux/train/cat.10650.jpg
#   inflating: data/dogscatsredux/train/cat.10651.jpg
#   inflating: data/dogscatsredux/train/cat.10652.jpg
#   inflating: data/dogscatsredux/train/cat.10653.jpg
#   inflating: data/dogscatsredux/train/cat.10654.jpg
#   inflating: data/dogscatsredux/train/cat.10655.jpg
#   inflating: data/dogscatsredux/train/cat.10656.jpg
#   inflating: data/dogscatsredux/train/cat.10657.jpg
#   inflating: data/dogscatsredux/train/cat.10658.jpg
#   inflating: data/dogscatsredux/train/cat.10659.jpg
#   inflating: data/dogscatsredux/train/cat.1066.jpg
#   inflating: data/dogscatsredux/train/cat.10660.jpg
#   inflating: data/dogscatsredux/train/cat.10661.jpg
#   inflating: data/dogscatsredux/train/cat.10662.jpg
#   inflating: data/dogscatsredux/train/cat.10663.jpg
#   inflating: data/dogscatsredux/train/cat.10664.jpg
#   inflating: data/dogscatsredux/train/cat.10665.jpg
#   inflating: data/dogscatsredux/train/cat.10666.jpg
#   inflating: data/dogscatsredux/train/cat.10667.jpg
#   inflating: data/dogscatsredux/train/cat.10668.jpg
#   inflating: data/dogscatsredux/train/cat.10669.jpg
#   inflating: data/dogscatsredux/train/cat.1067.jpg
#   inflating: data/dogscatsredux/train/cat.10670.jpg
#   inflating: data/dogscatsredux/train/cat.10671.jpg
#   inflating: data/dogscatsredux/train/cat.10672.jpg
#   inflating: data/dogscatsredux/train/cat.10673.jpg
#   inflating: data/dogscatsredux/train/cat.10674.jpg
#   inflating: data/dogscatsredux/train/cat.10675.jpg
#   inflating: data/dogscatsredux/train/cat.10676.jpg
#   inflating: data/dogscatsredux/train/cat.10677.jpg
#   inflating: data/dogscatsredux/train/cat.10678.jpg
#   inflating: data/dogscatsredux/train/cat.10679.jpg
#   inflating: data/dogscatsredux/train/cat.1068.jpg
#   inflating: data/dogscatsredux/train/cat.10680.jpg
#   inflating: data/dogscatsredux/train/cat.10681.jpg
#   inflating: data/dogscatsredux/train/cat.10682.jpg
#   inflating: data/dogscatsredux/train/cat.10683.jpg
#   inflating: data/dogscatsredux/train/cat.10684.jpg
#   inflating: data/dogscatsredux/train/cat.10685.jpg
#   inflating: data/dogscatsredux/train/cat.10686.jpg
#   inflating: data/dogscatsredux/train/cat.10687.jpg
#   inflating: data/dogscatsredux/train/cat.10688.jpg
#   inflating: data/dogscatsredux/train/cat.10689.jpg
#   inflating: data/dogscatsredux/train/cat.1069.jpg
#   inflating: data/dogscatsredux/train/cat.10690.jpg
#   inflating: data/dogscatsredux/train/cat.10691.jpg
#   inflating: data/dogscatsredux/train/cat.10692.jpg
#   inflating: data/dogscatsredux/train/cat.10693.jpg
#   inflating: data/dogscatsredux/train/cat.10694.jpg
#   inflating: data/dogscatsredux/train/cat.10695.jpg
#   inflating: data/dogscatsredux/train/cat.10696.jpg
#   inflating: data/dogscatsredux/train/cat.10697.jpg
#   inflating: data/dogscatsredux/train/cat.10698.jpg
#   inflating: data/dogscatsredux/train/cat.10699.jpg
#   inflating: data/dogscatsredux/train/cat.107.jpg
#   inflating: data/dogscatsredux/train/cat.1070.jpg
#   inflating: data/dogscatsredux/train/cat.10700.jpg
#   inflating: data/dogscatsredux/train/cat.10701.jpg
#   inflating: data/dogscatsredux/train/cat.10702.jpg
#   inflating: data/dogscatsredux/train/cat.10703.jpg
#   inflating: data/dogscatsredux/train/cat.10704.jpg
#   inflating: data/dogscatsredux/train/cat.10705.jpg
#   inflating: data/dogscatsredux/train/cat.10706.jpg
#   inflating: data/dogscatsredux/train/cat.10707.jpg
#   inflating: data/dogscatsredux/train/cat.10708.jpg
#   inflating: data/dogscatsredux/train/cat.10709.jpg
#   inflating: data/dogscatsredux/train/cat.1071.jpg
#   inflating: data/dogscatsredux/train/cat.10710.jpg
#   inflating: data/dogscatsredux/train/cat.10711.jpg
#   inflating: data/dogscatsredux/train/cat.10712.jpg
#   inflating: data/dogscatsredux/train/cat.10713.jpg
#   inflating: data/dogscatsredux/train/cat.10714.jpg
#   inflating: data/dogscatsredux/train/cat.10715.jpg
#   inflating: data/dogscatsredux/train/cat.10716.jpg
#   inflating: data/dogscatsredux/train/cat.10717.jpg
#   inflating: data/dogscatsredux/train/cat.10718.jpg
#   inflating: data/dogscatsredux/train/cat.10719.jpg
#   inflating: data/dogscatsredux/train/cat.1072.jpg
#   inflating: data/dogscatsredux/train/cat.10720.jpg
#   inflating: data/dogscatsredux/train/cat.10721.jpg
#   inflating: data/dogscatsredux/train/cat.10722.jpg
#   inflating: data/dogscatsredux/train/cat.10723.jpg
#   inflating: data/dogscatsredux/train/cat.10724.jpg
#   inflating: data/dogscatsredux/train/cat.10725.jpg
#   inflating: data/dogscatsredux/train/cat.10726.jpg
#   inflating: data/dogscatsredux/train/cat.10727.jpg
#   inflating: data/dogscatsredux/train/cat.10728.jpg
#   inflating: data/dogscatsredux/train/cat.10729.jpg
#   inflating: data/dogscatsredux/train/cat.1073.jpg
#   inflating: data/dogscatsredux/train/cat.10730.jpg
#   inflating: data/dogscatsredux/train/cat.10731.jpg
#   inflating: data/dogscatsredux/train/cat.10732.jpg
#   inflating: data/dogscatsredux/train/cat.10733.jpg
#   inflating: data/dogscatsredux/train/cat.10734.jpg
#   inflating: data/dogscatsredux/train/cat.10735.jpg
#   inflating: data/dogscatsredux/train/cat.10736.jpg
#   inflating: data/dogscatsredux/train/cat.10737.jpg
#   inflating: data/dogscatsredux/train/cat.10738.jpg
#   inflating: data/dogscatsredux/train/cat.10739.jpg
#   inflating: data/dogscatsredux/train/cat.1074.jpg
#   inflating: data/dogscatsredux/train/cat.10740.jpg
#   inflating: data/dogscatsredux/train/cat.10741.jpg
#   inflating: data/dogscatsredux/train/cat.10742.jpg
#   inflating: data/dogscatsredux/train/cat.10743.jpg
#   inflating: data/dogscatsredux/train/cat.10744.jpg
#   inflating: data/dogscatsredux/train/cat.10745.jpg
#   inflating: data/dogscatsredux/train/cat.10746.jpg
#   inflating: data/dogscatsredux/train/cat.10747.jpg
#   inflating: data/dogscatsredux/train/cat.10748.jpg
#   inflating: data/dogscatsredux/train/cat.10749.jpg
#   inflating: data/dogscatsredux/train/cat.1075.jpg
#   inflating: data/dogscatsredux/train/cat.10750.jpg
#   inflating: data/dogscatsredux/train/cat.10751.jpg
#   inflating: data/dogscatsredux/train/cat.10752.jpg
#   inflating: data/dogscatsredux/train/cat.10753.jpg
#   inflating: data/dogscatsredux/train/cat.10754.jpg
#   inflating: data/dogscatsredux/train/cat.10755.jpg
#   inflating: data/dogscatsredux/train/cat.10756.jpg
#   inflating: data/dogscatsredux/train/cat.10757.jpg
#   inflating: data/dogscatsredux/train/cat.10758.jpg
#   inflating: data/dogscatsredux/train/cat.10759.jpg
#   inflating: data/dogscatsredux/train/cat.1076.jpg
#   inflating: data/dogscatsredux/train/cat.10760.jpg
#   inflating: data/dogscatsredux/train/cat.10761.jpg
#   inflating: data/dogscatsredux/train/cat.10762.jpg
#   inflating: data/dogscatsredux/train/cat.10763.jpg
#   inflating: data/dogscatsredux/train/cat.10764.jpg
#   inflating: data/dogscatsredux/train/cat.10765.jpg
#   inflating: data/dogscatsredux/train/cat.10766.jpg
#   inflating: data/dogscatsredux/train/cat.10767.jpg
#   inflating: data/dogscatsredux/train/cat.10768.jpg
#   inflating: data/dogscatsredux/train/cat.10769.jpg
#   inflating: data/dogscatsredux/train/cat.1077.jpg
#   inflating: data/dogscatsredux/train/cat.10770.jpg
#   inflating: data/dogscatsredux/train/cat.10771.jpg
#   inflating: data/dogscatsredux/train/cat.10772.jpg
#   inflating: data/dogscatsredux/train/cat.10773.jpg
#   inflating: data/dogscatsredux/train/cat.10774.jpg
#   inflating: data/dogscatsredux/train/cat.10775.jpg
#   inflating: data/dogscatsredux/train/cat.10776.jpg
#   inflating: data/dogscatsredux/train/cat.10777.jpg
#   inflating: data/dogscatsredux/train/cat.10778.jpg
#   inflating: data/dogscatsredux/train/cat.10779.jpg
#   inflating: data/dogscatsredux/train/cat.1078.jpg
#   inflating: data/dogscatsredux/train/cat.10780.jpg
#   inflating: data/dogscatsredux/train/cat.10781.jpg
#   inflating: data/dogscatsredux/train/cat.10782.jpg
#   inflating: data/dogscatsredux/train/cat.10783.jpg
#   inflating: data/dogscatsredux/train/cat.10784.jpg
#   inflating: data/dogscatsredux/train/cat.10785.jpg
#   inflating: data/dogscatsredux/train/cat.10786.jpg
#   inflating: data/dogscatsredux/train/cat.10787.jpg
#   inflating: data/dogscatsredux/train/cat.10788.jpg
#   inflating: data/dogscatsredux/train/cat.10789.jpg
#   inflating: data/dogscatsredux/train/cat.1079.jpg
#   inflating: data/dogscatsredux/train/cat.10790.jpg
#   inflating: data/dogscatsredux/train/cat.10791.jpg
#   inflating: data/dogscatsredux/train/cat.10792.jpg
#   inflating: data/dogscatsredux/train/cat.10793.jpg
#   inflating: data/dogscatsredux/train/cat.10794.jpg
#   inflating: data/dogscatsredux/train/cat.10795.jpg
#   inflating: data/dogscatsredux/train/cat.10796.jpg
#   inflating: data/dogscatsredux/train/cat.10797.jpg
# ...
#   inflating: data/dogscatsredux/test/9699.jpg
#   inflating: data/dogscatsredux/test/97.jpg
#   inflating: data/dogscatsredux/test/970.jpg
#   inflating: data/dogscatsredux/test/9700.jpg
#   inflating: data/dogscatsredux/test/9701.jpg
#   inflating: data/dogscatsredux/test/9702.jpg
#   inflating: data/dogscatsredux/test/9703.jpg
#   inflating: data/dogscatsredux/test/9704.jpg
#   inflating: data/dogscatsredux/test/9705.jpg
#   inflating: data/dogscatsredux/test/9706.jpg
#   inflating: data/dogscatsredux/test/9707.jpg
#   inflating: data/dogscatsredux/test/9708.jpg
#   inflating: data/dogscatsredux/test/9709.jpg
#   inflating: data/dogscatsredux/test/971.jpg
#   inflating: data/dogscatsredux/test/9710.jpg
#   inflating: data/dogscatsredux/test/9711.jpg
#   inflating: data/dogscatsredux/test/9712.jpg
#   inflating: data/dogscatsredux/test/9713.jpg
#   inflating: data/dogscatsredux/test/9714.jpg
#   inflating: data/dogscatsredux/test/9715.jpg
#   inflating: data/dogscatsredux/test/9716.jpg
#   inflating: data/dogscatsredux/test/9717.jpg
#   inflating: data/dogscatsredux/test/9718.jpg
#   inflating: data/dogscatsredux/test/9719.jpg
#   inflating: data/dogscatsredux/test/972.jpg
#   inflating: data/dogscatsredux/test/9720.jpg
#   inflating: data/dogscatsredux/test/9721.jpg
#   inflating: data/dogscatsredux/test/9722.jpg
#   inflating: data/dogscatsredux/test/9723.jpg
#   inflating: data/dogscatsredux/test/9724.jpg
#   inflating: data/dogscatsredux/test/9725.jpg
#   inflating: data/dogscatsredux/test/9726.jpg
#   inflating: data/dogscatsredux/test/9727.jpg
#   inflating: data/dogscatsredux/test/9728.jpg
#   inflating: data/dogscatsredux/test/9729.jpg
#   inflating: data/dogscatsredux/test/973.jpg
#   inflating: data/dogscatsredux/test/9730.jpg
#   inflating: data/dogscatsredux/test/9731.jpg
#   inflating: data/dogscatsredux/test/9732.jpg
#   inflating: data/dogscatsredux/test/9733.jpg
#   inflating: data/dogscatsredux/test/9734.jpg
#   inflating: data/dogscatsredux/test/9735.jpg
#   inflating: data/dogscatsredux/test/9736.jpg
#   inflating: data/dogscatsredux/test/9737.jpg
#   inflating: data/dogscatsredux/test/9738.jpg
#   inflating: data/dogscatsredux/test/9739.jpg
#   inflating: data/dogscatsredux/test/974.jpg
#   inflating: data/dogscatsredux/test/9740.jpg
#   inflating: data/dogscatsredux/test/9741.jpg
#   inflating: data/dogscatsredux/test/9742.jpg
#   inflating: data/dogscatsredux/test/9743.jpg
#   inflating: data/dogscatsredux/test/9744.jpg
#   inflating: data/dogscatsredux/test/9745.jpg
#   inflating: data/dogscatsredux/test/9746.jpg
#   inflating: data/dogscatsredux/test/9747.jpg
#   inflating: data/dogscatsredux/test/9748.jpg
#   inflating: data/dogscatsredux/test/9749.jpg
#   inflating: data/dogscatsredux/test/975.jpg
#   inflating: data/dogscatsredux/test/9750.jpg
#   inflating: data/dogscatsredux/test/9751.jpg
#   inflating: data/dogscatsredux/test/9752.jpg
#   inflating: data/dogscatsredux/test/9753.jpg
#   inflating: data/dogscatsredux/test/9754.jpg
#   inflating: data/dogscatsredux/test/9755.jpg
#   inflating: data/dogscatsredux/test/9756.jpg
#   inflating: data/dogscatsredux/test/9757.jpg
#   inflating: data/dogscatsredux/test/9758.jpg
#   inflating: data/dogscatsredux/test/9759.jpg
#   inflating: data/dogscatsredux/test/976.jpg
#   inflating: data/dogscatsredux/test/9760.jpg
#   inflating: data/dogscatsredux/test/9761.jpg
#   inflating: data/dogscatsredux/test/9762.jpg
#   inflating: data/dogscatsredux/test/9763.jpg
#   inflating: data/dogscatsredux/test/9764.jpg
#   inflating: data/dogscatsredux/test/9765.jpg
#   inflating: data/dogscatsredux/test/9766.jpg
#   inflating: data/dogscatsredux/test/9767.jpg
#   inflating: data/dogscatsredux/test/9768.jpg
#   inflating: data/dogscatsredux/test/9769.jpg
#   inflating: data/dogscatsredux/test/977.jpg
#   inflating: data/dogscatsredux/test/9770.jpg
#   inflating: data/dogscatsredux/test/9771.jpg
#   inflating: data/dogscatsredux/test/9772.jpg
#   inflating: data/dogscatsredux/test/9773.jpg
#   inflating: data/dogscatsredux/test/9774.jpg
#   inflating: data/dogscatsredux/test/9775.jpg
#   inflating: data/dogscatsredux/test/9776.jpg
#   inflating: data/dogscatsredux/test/9777.jpg
#   inflating: data/dogscatsredux/test/9778.jpg
#   inflating: data/dogscatsredux/test/9779.jpg
#   inflating: data/dogscatsredux/test/978.jpg
#   inflating: data/dogscatsredux/test/9780.jpg
#   inflating: data/dogscatsredux/test/9781.jpg
#   inflating: data/dogscatsredux/test/9782.jpg
#   inflating: data/dogscatsredux/test/9783.jpg
#   inflating: data/dogscatsredux/test/9784.jpg
#   inflating: data/dogscatsredux/test/9785.jpg
#   inflating: data/dogscatsredux/test/9786.jpg
#   inflating: data/dogscatsredux/test/9787.jpg
#   inflating: data/dogscatsredux/test/9788.jpg
#   inflating: data/dogscatsredux/test/9789.jpg
#   inflating: data/dogscatsredux/test/979.jpg
#   inflating: data/dogscatsredux/test/9790.jpg
#   inflating: data/dogscatsredux/test/9791.jpg
#   inflating: data/dogscatsredux/test/9792.jpg
#   inflating: data/dogscatsredux/test/9793.jpg
#   inflating: data/dogscatsredux/test/9794.jpg
#   inflating: data/dogscatsredux/test/9795.jpg
#   inflating: data/dogscatsredux/test/9796.jpg
#   inflating: data/dogscatsredux/test/9797.jpg
#   inflating: data/dogscatsredux/test/9798.jpg
#   inflating: data/dogscatsredux/test/9799.jpg
#   inflating: data/dogscatsredux/test/98.jpg
#   inflating: data/dogscatsredux/test/980.jpg
#   inflating: data/dogscatsredux/test/9800.jpg
#   inflating: data/dogscatsredux/test/9801.jpg
#   inflating: data/dogscatsredux/test/9802.jpg
#   inflating: data/dogscatsredux/test/9803.jpg
#   inflating: data/dogscatsredux/test/9804.jpg
#   inflating: data/dogscatsredux/test/9805.jpg
#   inflating: data/dogscatsredux/test/9806.jpg
#   inflating: data/dogscatsredux/test/9807.jpg
#   inflating: data/dogscatsredux/test/9808.jpg
#   inflating: data/dogscatsredux/test/9809.jpg
#   inflating: data/dogscatsredux/test/981.jpg
#   inflating: data/dogscatsredux/test/9810.jpg
#   inflating: data/dogscatsredux/test/9811.jpg
#   inflating: data/dogscatsredux/test/9812.jpg
#   inflating: data/dogscatsredux/test/9813.jpg
#   inflating: data/dogscatsredux/test/9814.jpg
#   inflating: data/dogscatsredux/test/9815.jpg
#   inflating: data/dogscatsredux/test/9816.jpg
#   inflating: data/dogscatsredux/test/9817.jpg
#   inflating: data/dogscatsredux/test/9818.jpg
#   inflating: data/dogscatsredux/test/9819.jpg
#   inflating: data/dogscatsredux/test/982.jpg
#   inflating: data/dogscatsredux/test/9820.jpg
#   inflating: data/dogscatsredux/test/9821.jpg
#   inflating: data/dogscatsredux/test/9822.jpg
#   inflating: data/dogscatsredux/test/9823.jpg
#   inflating: data/dogscatsredux/test/9824.jpg
#   inflating: data/dogscatsredux/test/9825.jpg
#   inflating: data/dogscatsredux/test/9826.jpg
#   inflating: data/dogscatsredux/test/9827.jpg
#   inflating: data/dogscatsredux/test/9828.jpg
#   inflating: data/dogscatsredux/test/9829.jpg
#   inflating: data/dogscatsredux/test/983.jpg
#   inflating: data/dogscatsredux/test/9830.jpg
#   inflating: data/dogscatsredux/test/9831.jpg
#   inflating: data/dogscatsredux/test/9832.jpg
#   inflating: data/dogscatsredux/test/9833.jpg
#   inflating: data/dogscatsredux/test/9834.jpg
#   inflating: data/dogscatsredux/test/9835.jpg
#   inflating: data/dogscatsredux/test/9836.jpg
#   inflating: data/dogscatsredux/test/9837.jpg
#   inflating: data/dogscatsredux/test/9838.jpg
#   inflating: data/dogscatsredux/test/9839.jpg
#   inflating: data/dogscatsredux/test/984.jpg
#   inflating: data/dogscatsredux/test/9840.jpg
#   inflating: data/dogscatsredux/test/9841.jpg
#   inflating: data/dogscatsredux/test/9842.jpg
#   inflating: data/dogscatsredux/test/9843.jpg
#   inflating: data/dogscatsredux/test/9844.jpg
#   inflating: data/dogscatsredux/test/9845.jpg
#   inflating: data/dogscatsredux/test/9846.jpg
#   inflating: data/dogscatsredux/test/9847.jpg
#   inflating: data/dogscatsredux/test/9848.jpg
#   inflating: data/dogscatsredux/test/9849.jpg
#   inflating: data/dogscatsredux/test/985.jpg
#   inflating: data/dogscatsredux/test/9850.jpg
#   inflating: data/dogscatsredux/test/9851.jpg
#   inflating: data/dogscatsredux/test/9852.jpg
#   inflating: data/dogscatsredux/test/9853.jpg
#   inflating: data/dogscatsredux/test/9854.jpg
#   inflating: data/dogscatsredux/test/9855.jpg
#   inflating: data/dogscatsredux/test/9856.jpg
#   inflating: data/dogscatsredux/test/9857.jpg
#   inflating: data/dogscatsredux/test/9858.jpg
#   inflating: data/dogscatsredux/test/9859.jpg
#   inflating: data/dogscatsredux/test/986.jpg
#   inflating: data/dogscatsredux/test/9860.jpg
#   inflating: data/dogscatsredux/test/9861.jpg
#   inflating: data/dogscatsredux/test/9862.jpg
#   inflating: data/dogscatsredux/test/9863.jpg
#   inflating: data/dogscatsredux/test/9864.jpg
#   inflating: data/dogscatsredux/test/9865.jpg
#   inflating: data/dogscatsredux/test/9866.jpg
#   inflating: data/dogscatsredux/test/9867.jpg
#   inflating: data/dogscatsredux/test/9868.jpg
#   inflating: data/dogscatsredux/test/9869.jpg
#   inflating: data/dogscatsredux/test/987.jpg
#   inflating: data/dogscatsredux/test/9870.jpg
#   inflating: data/dogscatsredux/test/9871.jpg
#   inflating: data/dogscatsredux/test/9872.jpg
#   inflating: data/dogscatsredux/test/9873.jpg
#   inflating: data/dogscatsredux/test/9874.jpg
#   inflating: data/dogscatsredux/test/9875.jpg
#   inflating: data/dogscatsredux/test/9876.jpg
#   inflating: data/dogscatsredux/test/9877.jpg
#   inflating: data/dogscatsredux/test/9878.jpg
#   inflating: data/dogscatsredux/test/9879.jpg
#   inflating: data/dogscatsredux/test/988.jpg
#   inflating: data/dogscatsredux/test/9880.jpg
#   inflating: data/dogscatsredux/test/9881.jpg
#   inflating: data/dogscatsredux/test/9882.jpg
#   inflating: data/dogscatsredux/test/9883.jpg
#   inflating: data/dogscatsredux/test/9884.jpg
#   inflating: data/dogscatsredux/test/9885.jpg
#   inflating: data/dogscatsredux/test/9886.jpg
#   inflating: data/dogscatsredux/test/9887.jpg
#   inflating: data/dogscatsredux/test/9888.jpg
#   inflating: data/dogscatsredux/test/9889.jpg
#   inflating: data/dogscatsredux/test/989.jpg
#   inflating: data/dogscatsredux/test/9890.jpg
#   inflating: data/dogscatsredux/test/9891.jpg
#   inflating: data/dogscatsredux/test/9892.jpg
#   inflating: data/dogscatsredux/test/9893.jpg
#   inflating: data/dogscatsredux/test/9894.jpg
#   inflating: data/dogscatsredux/test/9895.jpg
#   inflating: data/dogscatsredux/test/9896.jpg
#   inflating: data/dogscatsredux/test/9897.jpg
#   inflating: data/dogscatsredux/test/9898.jpg
#   inflating: data/dogscatsredux/test/9899.jpg
#   inflating: data/dogscatsredux/test/99.jpg
#   inflating: data/dogscatsredux/test/990.jpg
#   inflating: data/dogscatsredux/test/9900.jpg
#   inflating: data/dogscatsredux/test/9901.jpg
#   inflating: data/dogscatsredux/test/9902.jpg
#   inflating: data/dogscatsredux/test/9903.jpg
#   inflating: data/dogscatsredux/test/9904.jpg
#   inflating: data/dogscatsredux/test/9905.jpg
#   inflating: data/dogscatsredux/test/9906.jpg
#   inflating: data/dogscatsredux/test/9907.jpg
#   inflating: data/dogscatsredux/test/9908.jpg
#   inflating: data/dogscatsredux/test/9909.jpg
#   inflating: data/dogscatsredux/test/991.jpg
#   inflating: data/dogscatsredux/test/9910.jpg
#   inflating: data/dogscatsredux/test/9911.jpg
#   inflating: data/dogscatsredux/test/9912.jpg
#   inflating: data/dogscatsredux/test/9913.jpg
#   inflating: data/dogscatsredux/test/9914.jpg
#   inflating: data/dogscatsredux/test/9915.jpg
#   inflating: data/dogscatsredux/test/9916.jpg
#   inflating: data/dogscatsredux/test/9917.jpg
#   inflating: data/dogscatsredux/test/9918.jpg
#   inflating: data/dogscatsredux/test/9919.jpg
#   inflating: data/dogscatsredux/test/992.jpg
#   inflating: data/dogscatsredux/test/9920.jpg
#   inflating: data/dogscatsredux/test/9921.jpg
#   inflating: data/dogscatsredux/test/9922.jpg
#   inflating: data/dogscatsredux/test/9923.jpg
#   inflating: data/dogscatsredux/test/9924.jpg
#   inflating: data/dogscatsredux/test/9925.jpg
#   inflating: data/dogscatsredux/test/9926.jpg
#   inflating: data/dogscatsredux/test/9927.jpg
#   inflating: data/dogscatsredux/test/9928.jpg
#   inflating: data/dogscatsredux/test/9929.jpg
#   inflating: data/dogscatsredux/test/993.jpg
#   inflating: data/dogscatsredux/test/9930.jpg
#   inflating: data/dogscatsredux/test/9931.jpg
#   inflating: data/dogscatsredux/test/9932.jpg
#   inflating: data/dogscatsredux/test/9933.jpg
#   inflating: data/dogscatsredux/test/9934.jpg
#   inflating: data/dogscatsredux/test/9935.jpg
#   inflating: data/dogscatsredux/test/9936.jpg
#   inflating: data/dogscatsredux/test/9937.jpg
#   inflating: data/dogscatsredux/test/9938.jpg
#   inflating: data/dogscatsredux/test/9939.jpg
#   inflating: data/dogscatsredux/test/994.jpg
#   inflating: data/dogscatsredux/test/9940.jpg
#   inflating: data/dogscatsredux/test/9941.jpg
#   inflating: data/dogscatsredux/test/9942.jpg
#   inflating: data/dogscatsredux/test/9943.jpg
#   inflating: data/dogscatsredux/test/9944.jpg
#   inflating: data/dogscatsredux/test/9945.jpg
#   inflating: data/dogscatsredux/test/9946.jpg
#   inflating: data/dogscatsredux/test/9947.jpg
#   inflating: data/dogscatsredux/test/9948.jpg
#   inflating: data/dogscatsredux/test/9949.jpg
#   inflating: data/dogscatsredux/test/995.jpg
#   inflating: data/dogscatsredux/test/9950.jpg
#   inflating: data/dogscatsredux/test/9951.jpg
#   inflating: data/dogscatsredux/test/9952.jpg
#   inflating: data/dogscatsredux/test/9953.jpg
#   inflating: data/dogscatsredux/test/9954.jpg
#   inflating: data/dogscatsredux/test/9955.jpg
#   inflating: data/dogscatsredux/test/9956.jpg
#   inflating: data/dogscatsredux/test/9957.jpg
#   inflating: data/dogscatsredux/test/9958.jpg
#   inflating: data/dogscatsredux/test/9959.jpg
#   inflating: data/dogscatsredux/test/996.jpg
#   inflating: data/dogscatsredux/test/9960.jpg
#   inflating: data/dogscatsredux/test/9961.jpg
#   inflating: data/dogscatsredux/test/9962.jpg
#   inflating: data/dogscatsredux/test/9963.jpg
#   inflating: data/dogscatsredux/test/9964.jpg
#   inflating: data/dogscatsredux/test/9965.jpg
#   inflating: data/dogscatsredux/test/9966.jpg
#   inflating: data/dogscatsredux/test/9967.jpg
#   inflating: data/dogscatsredux/test/9968.jpg
#   inflating: data/dogscatsredux/test/9969.jpg
#   inflating: data/dogscatsredux/test/997.jpg
#   inflating: data/dogscatsredux/test/9970.jpg
#   inflating: data/dogscatsredux/test/9971.jpg
#   inflating: data/dogscatsredux/test/9972.jpg
#   inflating: data/dogscatsredux/test/9973.jpg
#   inflating: data/dogscatsredux/test/9974.jpg
#   inflating: data/dogscatsredux/test/9975.jpg
#   inflating: data/dogscatsredux/test/9976.jpg
#   inflating: data/dogscatsredux/test/9977.jpg
#   inflating: data/dogscatsredux/test/9978.jpg
#   inflating: data/dogscatsredux/test/9979.jpg
#   inflating: data/dogscatsredux/test/998.jpg
#   inflating: data/dogscatsredux/test/9980.jpg
#   inflating: data/dogscatsredux/test/9981.jpg
#   inflating: data/dogscatsredux/test/9982.jpg
#   inflating: data/dogscatsredux/test/9983.jpg
#   inflating: data/dogscatsredux/test/9984.jpg
#   inflating: data/dogscatsredux/test/9985.jpg
#   inflating: data/dogscatsredux/test/9986.jpg
#   inflating: data/dogscatsredux/test/9987.jpg
#   inflating: data/dogscatsredux/test/9988.jpg
#   inflating: data/dogscatsredux/test/9989.jpg
#   inflating: data/dogscatsredux/test/999.jpg
#   inflating: data/dogscatsredux/test/9990.jpg
#   inflating: data/dogscatsredux/test/9991.jpg
#   inflating: data/dogscatsredux/test/9992.jpg
#   inflating: data/dogscatsredux/test/9993.jpg
#   inflating: data/dogscatsredux/test/9994.jpg
#   inflating: data/dogscatsredux/test/9995.jpg
#   inflating: data/dogscatsredux/test/9996.jpg
#   inflating: data/dogscatsredux/test/9997.jpg
#   inflating: data/dogscatsredux/test/9998.jpg
#   inflating: data/dogscatsredux/test/9999.jpg

# %%
training_directory = path + "/training"
validation_directory = path + "/validation"

# %%
# !mkdir -p {training_directory}/cat
# !mkdir -p {training_directory}/dog
# !mkdir -p {validation_directory}/cat
# !mkdir -p {validation_directory}/dog

# %%
from glob import glob
import os, shutil

filepaths = glob(os.path.join(path, "train", "*.*.*"))

# %%
import re

def extract_label(filepath):
    basename = os.path.basename(filepath)
    matcher = re.search("(.+)\.\d+\.jpg", basename)
    label = matcher.group(1)
    return label

labels = map(extract_label, filepaths)

# %%
import sklearn
import sklearn.model_selection
from sklearn.model_selection import StratifiedKFold

stratified_k_fold = StratifiedKFold(n_splits=10)
X = filepaths
y = labels
for training_set_indices, validation_set_indices in stratified_k_fold.split(X, y):
    # clear training and validation subdirectories
    for folder in [training_directory, validation_directory]:
        for label in ["cat", "dog"]:
            for file in os.listdir(folder + "/" + label):
                filepath = os.path.join(folder, label, file)
                if os.path.islink(filepath):
                    os.unlink(filepath)

    #print("%s %s" % (training_set_indices, validation_set_indices))
    for i in training_set_indices:
        training_filepath = filepaths[i]
        basename = os.path.basename(training_filepath)
        os.symlink("../../train/" + basename, training_directory + "/" + labels[i] + "/" + basename)
    for i in validation_set_indices:
        validation_filepath = filepaths[i]
        basename = os.path.basename(validation_filepath)
        os.symlink("../../train/" + basename, validation_directory + "/" + labels[i] + "/" + basename)
    break

# %% [markdown]
# # Use a pretrained VGG model with our **Vgg16** class

# %% [markdown]
# Our first step is simply to use a model that has been fully created for us, which can recognise a wide variety (1,000 categories) of images. We will use 'VGG', which won the 2014 Imagenet competition, and is a very simple model to create and understand. The VGG Imagenet team created both a larger, slower, slightly more accurate model (*VGG  19*) and a smaller, faster model (*VGG 16*). We will be using VGG 16 since the much slower performance of VGG19 is generally not worth the very minor improvement in accuracy.
#
# We have created a python class, *Vgg16*, which makes using the VGG 16 model very straightforward.

# %% [markdown]
# ## The punchline: state of the art custom model in 7 lines of code
#
# Here's everything you need to do to get >97% accuracy on the Dogs vs Cats dataset - we won't analyze how it works behind the scenes yet, since at this stage we're just going to focus on the minimum necessary to actually do useful work.

# %%
# As large as you can, but no larger than 64 is recommended. 
# If you have an older or cheaper GPU, you'll run out of memory, so will have to decrease this.
batch_size=64

# %%
# Import our class, and instantiate
from vgg16 import Vgg16

# %%
vgg = Vgg16()
# Grab a few images at a time for training and validation.
# NB: They must be in subdirectories named based on their category
batches = vgg.get_batches(path + '/training', batch_size=batch_size)
val_batches = vgg.get_batches(path + '/validation', batch_size=batch_size*2)
vgg.finetune(batches)

from keras.optimizers import Nadam
vgg.model.compile(optimizer=Nadam(), loss='categorical_crossentropy', metrics=['accuracy'])
vgg.fit(batches, val_batches, nb_epoch=1)
# Out:
# Found 22500 images belonging to 2 classes.
# Found 2500 images belonging to 2 classes.
# Epoch 1/1
# 22500/22500 [==============================] - 615s - loss: 0.1428 - acc: 0.9682 - val_loss: 0.0687 - val_acc: 0.9856

# %%
vgg.model.save_weights('vgg')

# %% [markdown]
# # Predictions on Test Data Set

# %%
test_dir = path + '/test'
# !mkdir -p {test_dir}/unknown
# !mv {test_dir}/*.* {test_dir}/unknown/
# Out:
# mv: cannot stat 'data/dogscatsredux/test/*.*': No such file or directory

# %%
batches, predictions = vgg.test(path + '/test/', batch_size = batch_size*2)
print("predictions:", predictions[:4])
filenames = batches.filenames
print("filenames:", filenames[:4])

is_dog = np.clip(predictions[:,1], 0.02, 0.98) # Since log loss is used as the evaluation metric, 
# we must not allow log of 0, which is undefined. Thus, we clip it to the accuracy at the end of training.
print("is_dog:", is_dog[:4])
# Out:
# Found 12500 images belonging to 1 classes.
# predictions: [[  1.0000e+00   9.6831e-15]
#  [  9.9999e-01   7.8982e-06]
#  [  1.0000e+00   7.4502e-12]
#  [  1.0000e+00   2.9305e-18]]
# filenames: ['unknown/9292.jpg', 'unknown/12026.jpg', 'unknown/9688.jpg', 'unknown/4392.jpg']
# is_dog: [ 0.02  0.02  0.02  0.02]

# %%
def extract_id(filepath):
    basename = os.path.basename(filepath)
    matcher = re.search("(\d+)\.jpg", basename)
    string_id = matcher.group(1)
    return int(string_id)   

identifiers = [int(extract_id(f)) for f in filenames]
print("ids:", identifiers[:4])

submission = np.stack([identifiers, is_dog], axis=1)
np.savetxt(path + '/submission.csv', submission, fmt='%d,%.32f', header='id,label', comments='')
# Out:
# ids: [9292, 12026, 9688, 4392]

# %%
# !kg submit {path}/submission.csv
# Out:
# Starting new HTTPS connection (1): www.kaggle.com

# %% [markdown]
# The code above will work for any image recognition task, with any number of categories! All you have to do is to put your images into one folder per category, and run the code above.
#
# Let's take a look at how this works, step by step...

# %% [markdown]
# ## Use Vgg16 for basic image recognition
#
# Let's start off by using the *Vgg16* class to recognise the main imagenet category for each image.
#
# We won't be able to enter the Cats vs Dogs competition with an Imagenet model alone, since 'cat' and 'dog' are not categories in Imagenet - instead each individual breed is a separate category. However, we can use it to see how well it can recognise the images, which is a good first step.

# %% [markdown]
# Vgg16 is built on top of *Keras* (which we will be learning much more about shortly!), a flexible, easy to use deep learning library that sits on top of Theano or Tensorflow. Keras reads groups of images and labels in *batches*, using a fixed directory structure, where images from each category for training must be placed in a separate folder.
#
# Let's grab batches of data from our training folder:

# %%
batches = vgg.get_batches(path + '/training', batch_size=4)
# Out:
# Found 22500 images belonging to 2 classes.

# %% [markdown]
# (BTW, when Keras refers to 'classes', it doesn't mean python classes - but rather it refers to the categories of the labels, such as 'pug', or 'tabby'.)
#
# *Batches* is just a regular python iterator. Each iteration returns both the images themselves, as well as the labels.

# %%
imgs,labels = next(batches)

# %% [markdown]
# As you can see, the labels for each image are an array, containing a 1 in the first position if it's a cat, and in the second position if it's a dog. This approach to encoding categorical variables, where an array containing just a single 1 in the position corresponding to the category, is very common in deep learning. It is called *one hot encoding*.
#
# The arrays contain two elements, because we have two categories (cat, and dog). If we had three categories (e.g. cats, dogs, and kangaroos), then the arrays would each contain two 0's, and one 1.

# %%
plots(imgs, titles=labels)

# %% [markdown]
# We can now pass the images to Vgg16's predict() function to get back probabilities, category indexes, and category names for each image's VGG prediction.

# %%
vgg.predict(imgs, True)
# Out:
# (array([ 1.,  1.,  1.,  1.], dtype=float32),
#  array([0, 0, 0, 1]),
#  [u'tench', u'tench', u'tench', u'goldfish'])

# %% [markdown]
# ## Use our Vgg16 class to finetune a Dogs vs Cats model
#
# To change our model so that it outputs "cat" vs "dog", instead of one of 1,000 very specific categories, we need to use a process called "finetuning". Finetuning looks from the outside to be identical to normal machine learning training - we provide a training set with data and labels to learn from, and a validation set to test against. The model learns a set of parameters based on the data provided.
#
# However, the difference is that we start with a model that is already trained to solve a similar problem. The idea is that many of the parameters should be very similar, or the same, between the existing model, and the model we wish to create. Therefore, we only select a subset of parameters to train, and leave the rest untouched. This happens automatically when we call *fit()* after calling *finetune()*.
#
# We create our batches just like before, and making the validation set available as well. A 'batch' (or *mini-batch* as it is commonly known) is simply a subset of the training data - we use a subset at a time when training or predicting, in order to speed up training, and to avoid running out of memory.

# %%
batch_size=64

# %%
batches = vgg.get_batches(path + '/training', batch_size=batch_size)
val_batches = vgg.get_batches(path + '/validation', batch_size=batch_size)
# Out:
# Found 22500 images belonging to 2 classes.
# Found 2500 images belonging to 2 classes.

# %% [markdown]
# Calling *finetune()* modifies the model such that it will be trained based on the data in the batches provided - in this case, to predict either 'dog' or 'cat'.

# %%
vgg.finetune(batches)

# %% [markdown]
# Finally, we *fit()* the parameters of the model using the training data, reporting the accuracy on the validation set after every epoch. (An *epoch* is one full pass through the training data.)

# %%
vgg.fit(batches, val_batches, nb_epoch=1)
# Out:
# Epoch 1/1
# 22500/22500 [==============================] - 659s - loss: 8.0465 - acc: 0.4999 - val_loss: 8.0590 - val_acc: 0.5000

# %% [markdown]
# That shows all of the steps involved in using the Vgg16 class to create an image recognition model using whatever labels you are interested in. For instance, this process could classify paintings by style, or leaves by type of disease, or satellite photos by type of crop, and so forth.
#
# Next up, we'll dig one level deeper to see what's going on in the Vgg16 class.

# %% [markdown]
# # Create a VGG model from scratch in Keras
#
# For the rest of this tutorial, we will not be using the Vgg16 class at all. Instead, we will recreate from scratch the functionality we just used. This is not necessary if all you want to do is use the existing model - but if you want to create your own models, you'll need to understand these details. It will also help you in the future when you debug any problems with your models, since you'll understand what's going on behind the scenes.

# %% [markdown]
# ## Model setup
#
# We need to import all the modules we'll be using from numpy, scipy, and keras:

# %%
from numpy.random import random, permutation
from scipy import misc, ndimage
from scipy.ndimage.interpolation import zoom

import keras
from keras import backend as K
from keras.utils.data_utils import get_file
from keras.models import Sequential, Model
from keras.layers.core import Flatten, Dense, Dropout, Lambda
from keras.layers import Input
from keras.layers.convolutional import Convolution2D, MaxPooling2D, ZeroPadding2D
from keras.optimizers import SGD, RMSprop
from keras.preprocessing import image

# %% [markdown]
# Let's import the mappings from VGG ids to imagenet category ids and descriptions, for display purposes later.

# %%
FILES_PATH = 'http://www.platform.ai/models/'; CLASS_FILE='imagenet_class_index.json'
# Keras' get_file() is a handy function that downloads files, and caches them for re-use later
fpath = get_file(CLASS_FILE, FILES_PATH+CLASS_FILE, cache_subdir='models')
with open(fpath) as f: class_dict = json.load(f)
# Convert dictionary with string indexes into an array
classes = [class_dict[str(i)][1] for i in range(len(class_dict))]

# %% [markdown]
# ## Model creation
#
# Creating the model involves creating the model architecture, and then loading the model weights into that architecture. We will start by defining the basic pieces of the VGG architecture.
#
# VGG has just one type of convolutional block, and one type of fully connected ('dense') block. Here's the convolutional block definition:

# %%
def ConvBlock(layers, model, filters):
    for i in range(layers): 
        model.add(ZeroPadding2D((1,1)))
        model.add(Convolution2D(filters, 3, 3, activation='relu'))
    model.add(MaxPooling2D((2,2), strides=(2,2)))

# %% [markdown]
# ...and here's the fully-connected definition.

# %%
def FCBlock(model):
    model.add(Dense(4096, activation='relu'))
    model.add(Dropout(0.5))

# %% [markdown]
# When the VGG model was trained in 2014, the creators subtracted the average of each of the three (R,G,B) channels first, so that the data for each channel had a mean of zero. Furthermore, their software that expected the channels to be in B,G,R order, whereas Python by default uses R,G,B. We need to preprocess our data to make these two changes, so that it is compatible with the VGG model:

# %%
# Mean of each channel as provided by VGG researchers
vgg_mean = np.array([123.68, 116.779, 103.939]).reshape((3,1,1))

def vgg_preprocess(x):
    x = x - vgg_mean     # subtract mean
    return x[:, ::-1]    # reverse axis bgr->rgb

# %% [markdown]
# Now we're ready to define the VGG model architecture - look at how simple it is, now that we have the basic blocks defined!

# %%
def VGG_16():
    model = Sequential()
    model.add(Lambda(vgg_preprocess, input_shape=(3,224,224)))

    ConvBlock(2, model, 64)
    ConvBlock(2, model, 128)
    ConvBlock(3, model, 256)
    ConvBlock(3, model, 512)
    ConvBlock(3, model, 512)

    model.add(Flatten())
    FCBlock(model)
    FCBlock(model)
    model.add(Dense(1000, activation='softmax'))
    return model

# %% [markdown]
# We'll learn about what these different blocks do later in the course. For now, it's enough to know that:
#
# - Convolution layers are for finding patterns in images
# - Dense (fully connected) layers are for combining patterns across an image
#
# Now that we've defined the architecture, we can create the model like any python object:

# %%
model = VGG_16()

# %% [markdown]
# As well as the architecture, we need the weights that the VGG creators trained. The weights are the part of the model that is learnt from the data, whereas the architecture is pre-defined based on the nature of the problem.
#
# Downloading pre-trained weights is much preferred to training the model ourselves, since otherwise we would have to download the entire Imagenet archive, and train the model for many days! It's very helpful when researchers release their weights, as they did here.

# %%
fpath = get_file('vgg16.h5', FILES_PATH+'vgg16.h5', cache_subdir='models')
model.load_weights(fpath)

# %% [markdown]
# ## Getting imagenet predictions
#
# The setup of the imagenet model is now complete, so all we have to do is grab a batch of images and call *predict()* on them.

# %%
batch_size = 4

# %% [markdown]
# Keras provides functionality to create batches of data from directories containing images; all we have to do is to define the size to resize the images to, what type of labels to create, whether to randomly shuffle the images, and how many images to include in each batch. We use this little wrapper to define some helpful defaults appropriate for imagenet data:

# %%
def get_batches(dirname, gen=image.ImageDataGenerator(), shuffle=True, 
                batch_size=batch_size, class_mode='categorical'):
    return gen.flow_from_directory(path+dirname, target_size=(224,224), 
                class_mode=class_mode, shuffle=shuffle, batch_size=batch_size)

# %% [markdown]
# From here we can use exactly the same steps as before to look at predictions from the model.

# %%
batches = get_batches('/training', batch_size=batch_size)
val_batches = get_batches('/validation', batch_size=batch_size)
imgs,labels = next(batches)

# This shows the 'ground truth'
plots(imgs, titles=labels)
# Out:
# Found 22500 images belonging to 2 classes.
# Found 2500 images belonging to 2 classes.

# %% [markdown]
# The VGG model returns 1,000 probabilities for each image, representing the probability that the model assigns to each possible imagenet category for each image. By finding the index with the largest probability (with *np.argmax()*) we can find the predicted label.

# %%
def pred_batch(imgs):
    preds = model.predict(imgs)
    idxs = np.argmax(preds, axis=1)

    print('Shape: {}'.format(preds.shape))
    print('First 5 classes: {}'.format(classes[:5]))
    print('First 5 probabilities: {}\n'.format(preds[0, :5]))
    print('Predictions prob/class: ')
    
    for i in range(len(idxs)):
        idx = idxs[i]
        print ('  {:.4f}/{}'.format(preds[i, idx], classes[idx]))

# %%
pred_batch(imgs)
# Out:
# Shape: (4, 1000)
# First 5 classes: [u'tench', u'goldfish', u'great_white_shark', u'tiger_shark', u'hammerhead']
# First 5 probabilities: [  9.4213e-11   5.8187e-10   9.6656e-10   2.0326e-09   2.4369e-09]
#
# Predictions prob/class:
#   0.7505/cocker_spaniel
#   0.7466/German_shepherd
#   0.2286/Egyptian_cat
#   0.7986/Siamese_cat
